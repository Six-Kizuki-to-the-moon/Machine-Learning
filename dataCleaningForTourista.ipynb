# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import tensorflow_recommenders as tfrs

# %% [markdown]
# <H2>Take the dataset</H2>
# <p>For now just use dataset from list place</p>

# %%
data = pd.read_csv('dataset/tourism_with_id.csv')

# %%
data.head()
# Out:
#    Place_Id                         Place_Name  \
# 0         1                   Monumen Nasional
# 1         2                           Kota Tua
# 2         3                      Dunia Fantasi
# 3         4  Taman Mini Indonesia Indah (TMII)
# 4         5           Atlantis Water Adventure
#
#                                          Description       Category     City  \
# 0  Monumen Nasional atau yang populer disingkat d...         Budaya  Jakarta
# 1  Kota tua di Jakarta, yang juga bernama Kota Tu...         Budaya  Jakarta
# 2  Dunia Fantasi atau disebut juga Dufan adalah t...  Taman Hiburan  Jakarta
# 3  Taman Mini Indonesia Indah merupakan suatu kaw...  Taman Hiburan  Jakarta
# 4  Atlantis Water Adventure atau dikenal dengan A...  Taman Hiburan  Jakarta
#
#      Price  Rating                                       Coordinate      Lat  \
# 0   20,000     4.6          {'lat': -6.1753924, 'lng': 106.8271528} -6.17539
# ...

# %% [markdown]
# <h2>Drop unusefull column</h2>
# <li> Description </li>
# <li> Coordinate, supaya untuk input dari usernya lebih mudah mungkin? </li>
# <li>Dapat pilih salah satu antara drop Place_id / Place_Name</li>

# %% [markdown]
# Untuk beberapa alasan sepertinya lebih baik merubah Categorical item seperti column 'Category' & 'City' dapat dibuat menjadi one-hot-encoding

# %%
data = data.drop(['Description', 'Coordinate'], axis=1)

# %%
data.head()
# Out:
#    Place_Id                         Place_Name       Category     City  \
# 0         1                   Monumen Nasional         Budaya  Jakarta
# 1         2                           Kota Tua         Budaya  Jakarta
# 2         3                      Dunia Fantasi  Taman Hiburan  Jakarta
# 3         4  Taman Mini Indonesia Indah (TMII)  Taman Hiburan  Jakarta
# 4         5           Atlantis Water Adventure  Taman Hiburan  Jakarta
#
#      Price  Rating      Lat      Long
# 0   20,000     4.6 -6.17539  106.8272
# 1    5,000     4.6 -6.13764  106.8171
# 2  270,000     4.6 -6.12531  106.8335
# 3   10,000     4.5 -6.30245  106.8952
# 4   94,000     4.5 -6.12419  106.8391

# %% [markdown]
# <h2>Pre processing</h2>
# <li>Rubah variable pada column price menjadi float</li>

# %%
# Preprocessing kolom Price
data['Price'] = data['Price'].str.replace(',', '').astype(float)

# %%
data.head()
# Out:
#    Place_Id                         Place_Name       Category     City  \
# 0         1                   Monumen Nasional         Budaya  Jakarta
# 1         2                           Kota Tua         Budaya  Jakarta
# 2         3                      Dunia Fantasi  Taman Hiburan  Jakarta
# 3         4  Taman Mini Indonesia Indah (TMII)  Taman Hiburan  Jakarta
# 4         5           Atlantis Water Adventure  Taman Hiburan  Jakarta
#
#       Price  Rating      Lat      Long
# 0   20000.0     4.6 -6.17539  106.8272
# 1    5000.0     4.6 -6.13764  106.8171
# 2  270000.0     4.6 -6.12531  106.8335
# 3   10000.0     4.5 -6.30245  106.8952
# 4   94000.0     4.5 -6.12419  106.8391
