# %%
# !pip install googlemaps
# Out:
# ...
#   Using cached googlemaps-4.10.0.tar.gz (33 kB)
# ...
#   Created wheel for googlemaps: filename=googlemaps-4.10.0-py3-none-any.whl size=40716 sha256=432a24ac52a9fc4efb3121812919f73e698308590d57359a80654af10380d9ee
#   Stored in directory: c:\users\elghi\appdata\local\pip\cache\wheels\18\8a\74\69684f55a6b3e396f2b8e129f98b576cb02d6bebe66a0c3999
# Successfully built googlemaps
# ...

# %%
import googlemaps
import pandas as pd
import time

# %%
cities_jakarta = ['Jakarta Selatan', 'Jakarta Utara', 
                  'Jakarta Timur', 'Jakarta Barat', 'Jakarta Pusat']

# %%
# Initialize the Google Maps client with your API key
api_key = 'AIzaSyBr7aAxeDamZx5L3ENlk9AW1dQHrSNS1ZM'
gmaps = googlemaps.Client(api_key)
df = pd.DataFrame(columns=['Name', 'Rating', 'Address', 'Location'])
def scrape_hotels_in_city(df, gmaps, city):

    # Define the search query
    query = 'hotel'

    # Perform a text search for hotels in the specified city
    places_result = gmaps.places(query, location=city)

    # Extract relevant data from the initial API response
    places = places_result['results']
    data = []
    for place in places:
        name = place['name']
        rating = place.get('rating', 'N/A')
        address = place['formatted_address']
        location = place['geometry']['location']
        data.append({'Name': name, 'Rating': rating, 'Address': address, 'Location': location})
        time.sleep(2)

    # Check if there are more results available
    for i in range(2):
        if 'next_page_token' not in places_result:
            break

        places_result = gmaps.places(query, location=city, page_token=places_result['next_page_token'])
        places = places_result['results']
        for place in places:
            name = place['name']
            rating = place.get('rating', 'N/A')
            address = place['formatted_address']
            location = place['geometry']['location']
            data.append({'Name': name, 'Rating': rating, 'Address': address, 'Location': location})
        time.sleep(2)

    # Create a DataFrame from the collected data and concat to df
    new_df = pd.DataFrame(data)
    df = pd.concat([new_df,df.loc[:]]).reset_index(drop=True)
    
    return df

# %%
# Jakarta
for city in cities_jakarta:
    df = scrape_hotels_in_city(df, gmaps, city)

df
# Out:
#                                                   Name  Rating  \
# 0    ASTON Priority Simatupang Hotel & Conference C...     4.7
# 1                    Hotel Indonesia Kempinski Jakarta     4.7
# 2                     Urbanest Inn House TB Simatupang     4.5
# 3                     The London Living Kebagusan City     4.3
# 4                                           Cove Ostin     4.9
# ..                                                 ...     ...
# 295                              KOST EXCLUSIVE BARKAH     4.1
# 296                                      Nur Residence     4.7
# 297                   OYO Life 2958 Kost Lenteng Agung     4.3
# 298                                     The Hatu Hotel     4.3
# 299                               JASMINE RESIDENCE 33     3.1
#
#                                                Address  \
# 0    No.Kav. 9, Jl. Let. Jend Jl. TB Simatupang No....
# 1    Jl. M.H. Thamrin No.1, RT.1/RW.5, Menteng, Kec...
# ...

# %%
df.to_csv('Hotels_Jakarta.csv', index=False)

# %%
# raw API result
places_result
# Out:
# {'html_attributions': [],
#  'results': [{'business_status': 'OPERATIONAL',
#    'formatted_address': 'Kawasan, Jl. Melawai 6 No.27, RT.3/RW.1, Melawai, Kec. Kby. Baru, Jakarta, Daerah Khusus Ibukota Jakarta 12160, Indonesia',
#    'geometry': {'location': {'lat': -6.244239599999999, 'lng': 106.7996644},
#     'viewport': {'northeast': {'lat': -6.242995870107277,
#       'lng': 106.8010147798927},
#      'southwest': {'lat': -6.245695529892721, 'lng': 106.7983151201073}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'M Hotel Jakarta',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3456,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/102268570086807596454">A Google User</a>'],
# ...
